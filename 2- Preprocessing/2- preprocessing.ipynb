# %% [markdown]
# Preprocessing data

# %%
import os
import pandas as pd
import numpy as np
import datetime
import fastparquet as fp
from dateutil import parser
import calendar
import pickle

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ellio\\Desktop\\Python\\scripts\\ML_flight_cancellation_prediction\\2- Preprocessing'

# %% [markdown]
# ## Utility functions

# %%
def cols_to_snake(df):
    ''' function to make all column headers snake case
    
    Input: pd dataframe
    Outputs: pd dataframe with clean headers
    
    '''
        
    df.columns = df.columns.astype("str")
    df.columns = df.columns.str.lower()
    df.columns = df.columns.map(lambda x : x.replace("-", "_").replace(" ", "_").replace("/", "").replace(".", "_"))
    return df


def create_data_dict(dataframe, csv_name):
    
    """Extracts and prints a data dictionary to help with extracting and cleaning, needs manual 
    additions for variable descriptions
    
    Parameters
    ----------
    Input: dataframe: a dataframe for which you would like a dictionary
           csv_name: a 'string' which will become part of your csv file name
    
    Output: a dataframe with the variable names and data types. 
    
    Will need to manually enter in addition: data categories, variable descriptions, include (y/n)? and validations"""

    data_dict_cars = pd.DataFrame({
        "variable": list(data.columns),
        "data_type": data.dtypes,
    })
    
    data_dict_cars.to_csv(str('2-' + csv_name + '.csv'))
    
    return data_dict_cars

# %%
#read data
data = pd.read_parquet('C:\\Users\\ellio\\Desktop\\Python\\scripts\\ML_flight_cancellation_prediction\\datasets\\1.1-full_departures_3012.parquet.gzip')

# %%
# regularise headers to snakecase
data = cols_to_snake(data)
data.head(2)
# Out:
#         type   status departure_iatacode departure_icaocode  \
# 0  departure  unknown                lhr               egll
# 1  departure  unknown                lhr               egll
#
#   departure_terminal departure_scheduledtime arrival_iatacode  \
# 0                  2     2020-05-15 06:40:00              arn
# 1                  2     2020-05-15 06:40:00              arn
#
#   arrival_icaocode arrival_terminal    arrival_scheduledtime  ...  \
# 0             essa                5  2020-05-15t10:05:00.000  ...
# 1             essa                5  2020-05-15t10:05:00.000  ...
#
#   departure_actualtime departure_estimatedrunway departure_actualrunway  \
# 0                 None                      None                   None
# 1                 None                      None                   None
#
#   arrival_estimatedtime arrival_baggage arrival_delay arrival_gate  \
# 0                  None            None           NaN         None
# 1                  None            None           NaN         None
#
#   arrival_actualtime arrival_estimatedrunway arrival_actualrunway
# 0               None                    None                 None
# 1               None                    None                 None
#
# [2 rows x 35 columns]

# %%
# create a data dictionary

# comment this out so not to overwrite the manual adds

#create_data_dict(data, 'departures_data_dict')

data_dict = pd.read_csv('2-departures_data_dict.csv')

display(data_dict)
# Out:
#     Unnamed: 0               Unnamed: 0.1                   variable  \
# 0            0                       type                       type
# 1            1                     status                     status
# 2            2         departure_iatacode         departure_iatacode
# 3            3         departure_icaocode         departure_icaocode
# 4            4         departure_terminal         departure_terminal
# 5            5    departure_scheduledtime    departure_scheduledtime
# 6            8           arrival_terminal           arrival_terminal
# 7            9      arrival_scheduledtime      arrival_scheduledtime
# 8           10               airline_name               airline_name
# 9           13              flight_number              flight_number
# 10          14          flight_iatanumber          flight_iatanumber
# 11          16    codeshared_airline_name    codeshared_airline_name
# 12          19   codeshared_flight_number   codeshared_flight_number
# 13          22             departure_gate             departure_gate
# 14          23            departure_delay            departure_delay
# 15          24    departure_estimatedtime    departure_estimatedtime
# 16          25       departure_actualtime       departure_actualtime
# 17          26  departure_estimatedrunway  departure_estimatedrunway
# 18          27     departure_actualrunway     departure_actualrunway
#
#          data_type       var_type include
# 0           object           none       y
# 1           object  flight_status       y
# 2           object             id       y
# 3           object             id       y
# 4           object       terminal       y
# 5   datetime64[ns]           time       y
# 6           object       terminal       y
# 7           object           time       y
# 8           object        airline       y
# 9           object             id       y
# 10          object             id       y
# 11          object           name       y
# 12          object             id       y
# 13          object           gate       y
# 14         float64           time       y
# 15          object           time       y
# 16          object           time       y
# 17          object         runway       y
# 18          object         runway       y

# %%
# Remove unwanted columns - annotated in dictionary by include = 'n'
columns = data_dict.loc[data_dict.eval("include == 'y'"), "variable"]  #extract all of the drivetrain types from the data dictionary & keep the variable only that becomes columns

data = data[columns]

data.head(3)

# write to new data.dict so as not to query missing columns
data_dict = data_dict.loc[data_dict.eval("include == 'y'"), :]

data_dict.to_csv('2-departures_data_dict.csv')

#only included value in our data dictionary
data_dict.head(3)
# Out:
#    Unnamed: 0        Unnamed: 0.1            variable data_type  \
# 0           0                type                type    object
# 1           1              status              status    object
# 2           2  departure_iatacode  departure_iatacode    object
#
#         var_type include
# 0           none       y
# 1  flight_status       y
# 2             id       y

# %% [markdown]
# As this is an exercise in cancelled flights, we will be using the scheduled date as the date timestamp as the true reference

# %%
# dates and times to dates and time format

# Remove unwanted columns

time_columns = data_dict.loc[data_dict.eval("var_type == 'time'"), "variable"]  #extract all of the drivetrain types from the data dictionary & keep the variable only that becomes columns

time_cols = data[time_columns]

time_cols_good_formats = time_cols.apply(pd.to_datetime, errors='coerce')

time_cols_good_formats

no_bad_time_data = data.drop(columns = time_cols)

time_parsed_data = pd.concat([no_bad_time_data, time_cols_good_formats], axis = 1)

time_parsed_data.head(2)
# Out:
#         type   status departure_iatacode departure_icaocode  \
# 0  departure  unknown                lhr               egll
# 1  departure  unknown                lhr               egll
#
#   departure_terminal arrival_terminal                airline_name  \
# 0                  2                5  thai airways international
# 1                  2                5                         sas
#
#   flight_number flight_iatanumber codeshared_airline_name  \
# 0          6225            tg6225                     sas
# 1          1530            sk1530                    None
#
#   codeshared_flight_number departure_gate departure_estimatedrunway  \
# 0                     1530           None                      None
# 1                     None           None                      None
#
#   departure_actualrunway departure_scheduledtime arrival_scheduledtime  \
# 0                   None     2020-05-15 06:40:00   2020-05-15 10:05:00
# 1                   None     2020-05-15 06:40:00   2020-05-15 10:05:00
#
#   departure_delay departure_estimatedtime departure_actualtime
# 0             NaT                     NaT                  NaT
# 1             NaT                     NaT                  NaT

# %%
# split date and time from our reference date - departure_scheduledtime 

#get time of day and week day for EDA

time_parsed_data['weekday'] = time_parsed_data['departure_scheduledtime'].dt.day_name()
time_parsed_data['time_of_day'] = time_parsed_data['departure_scheduledtime'].dt.time
time_parsed_data['date'] = time_parsed_data['departure_scheduledtime'].dt.date

time_parsed_data.head(3)
# Out:
#         type   status departure_iatacode departure_icaocode  \
# 0  departure  unknown                lhr               egll
# 1  departure  unknown                lhr               egll
# 2  departure  unknown                lhr               egll
#
#   departure_terminal arrival_terminal                airline_name  \
# 0                  2                5  thai airways international
# 1                  2                5                         sas
# 2                  2                3                         sas
#
#   flight_number flight_iatanumber codeshared_airline_name  ...  \
# 0          6225            tg6225                     sas  ...
# 1          1530            sk1530                    None  ...
# 2           500             sk500                    None  ...
#
#   departure_estimatedrunway departure_actualrunway departure_scheduledtime  \
# 0                      None                   None     2020-05-15 06:40:00
# 1                      None                   None     2020-05-15 06:40:00
# 2                      None                   None     2020-05-15 06:45:00
#
#   arrival_scheduledtime departure_delay departure_estimatedtime  \
# 0   2020-05-15 10:05:00             NaT                     NaT
# 1   2020-05-15 10:05:00             NaT                     NaT
# 2   2020-05-15 09:35:00             NaT                     NaT
#
#   departure_actualtime weekday time_of_day        date
# 0                  NaT  Friday    06:40:00  2020-05-15
# 1                  NaT  Friday    06:40:00  2020-05-15
# 2                  NaT  Friday    06:45:00  2020-05-15
#
# [3 rows x 22 columns]

# %% [markdown]
# preprocessing largely done - write pickle to datasets and start EDA - using a pickle file to save the date format

# %%
# set our outcome variable

time_parsed_data['cancelled_outcome'] = np.where(time_parsed_data['status']=='cancelled', 1, 0)

#cool

# %%
time_parsed_data.to_pickle(path = 'C:\\Users\\ellio\\Desktop\\Python\\scripts\\ML_flight_cancellation_prediction\\datasets\\2-formatted_data_for_EDA.pickle')
